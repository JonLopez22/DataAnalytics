# %% [markdown]
# # Data Analysis Notes
#
# ## Goals
# - Clean Data
# - Analyze trends
# - Build model
#
# ### Sample Code

# %%
'''python'''
x = 10
y = 20
print(x + y)
# Out:
# 30

# %%
cd
# Out:
# C:\Users\jonathanlopez

# %%
cd ~/Documents/DataAnalytics/week-6
# Out:
# C:\Users\jonathanlopez\Documents\DataAnalytics\week-6
