# %%
import numpy as np

# %%
# 1. 

arrA = np.array([
    [11, 12, 13],
    [14, 15, 16]
])

print(arrA)
# Out:
# [[11 12 13]
#  [14 15 16]]

# %%
# 2.
for x in arrA:
    print(x * 2)
# Out:
# [22 24 26]
# [28 30 32]

# %%
# 3.
for x in arrA:
    for y in x:
        loop_result = y * 2
        #4
        print(loop_result)
# Out:
# 22
# 24
# 26
# 28
# 30
# 32
