# %%
import pandas as pd

# Creating a dataframe
data = [
    ["Alice", 20],
    ["Bob", 22],
    ["Charlie", 21]
]

df = pd.DataFrame(data, columns=["Name", "Age"])
print(df)
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   22
# 2  Charlie   21
